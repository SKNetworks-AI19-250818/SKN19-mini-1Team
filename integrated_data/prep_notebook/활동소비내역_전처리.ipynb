# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. 데이터 로드
tn_activity_consume_his_df = pd.read_csv('../../data/training/TL_csv/tn_activity_consume_his_활동소비내역_E.csv')
tn_activity_consume_his_df
# Out:
#        TRAVEL_ID  VISIT_AREA_ID  ACTIVITY_TYPE_CD  ACTIVITY_TYPE_SEQ  \
# 0      e_e002053     2306030007                 2                  0
# 1      e_e001001     2306090003                 1                  0
# 2      e_e009156     2308260006                 1                  0
# 3      e_e002077     2306010003                 1                  0
# 4      e_e001949     2306010005                 1                  0
# ...          ...            ...               ...                ...
# 11734  g_g010556     2309020008                 1                  0
# 11735  h_h003275     2308270002                 3                  0
# 11736  h_h003275     2308270002                 3                  1
# 11737  h_h003275     2308270004                 1                  0
# 11738  h_h003275     2308270005                 3                  0
#
#        CONSUME_HIS_SEQ  CONSUME_HIS_SNO  PAYMENT_NUM          BRNO  \
# 0                    0                1            1  4.013801e+09
# ...

# %%
# 2. 데이터 구조 및 기초 통계 확인
tn_activity_consume_his_df.head()
# Out:
#    TRAVEL_ID  VISIT_AREA_ID  ACTIVITY_TYPE_CD  ACTIVITY_TYPE_SEQ  \
# 0  e_e002053     2306030007                 2                  0
# 1  e_e001001     2306090003                 1                  0
# 2  e_e009156     2308260006                 1                  0
# 3  e_e002077     2306010003                 1                  0
# 4  e_e001949     2306010005                 1                  0
#
#    CONSUME_HIS_SEQ  CONSUME_HIS_SNO  PAYMENT_NUM          BRNO   STORE_NM  \
# 0                0                1            1  4.013801e+09         CU
# 1                0                1            2  1.338122e+09  가평(춘천)휴게소
# 2                0                1            2  2.204101e+09       개항백화
# 3                0                1            4  8.912202e+09      경주십원빵
# 4                0                1            2  6.323501e+09       단일서울
#
#               ROAD_NM_ADDR            LOTNO_ADDR  ROAD_NM_CD      LOTNO_CD  \
# ...

# %%
tn_activity_consume_his_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11739 entries, 0 to 11738
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TRAVEL_ID          11739 non-null  object
#  1   VISIT_AREA_ID      11739 non-null  int64
#  2   ACTIVITY_TYPE_CD   11739 non-null  int64
#  3   ACTIVITY_TYPE_SEQ  11739 non-null  int64
#  4   CONSUME_HIS_SEQ    11739 non-null  int64
#  5   CONSUME_HIS_SNO    11739 non-null  int64
#  6   PAYMENT_NUM        11739 non-null  int64
#  7   BRNO               9805 non-null   float64
#  8   STORE_NM           11690 non-null  object
#  9   ROAD_NM_ADDR       11390 non-null  object
#  10  LOTNO_ADDR         7870 non-null   object
#  11  ROAD_NM_CD         10242 non-null  float64
#  12  LOTNO_CD           10242 non-null  float64
#  13  PAYMENT_DT         10361 non-null  object
#  14  PAYMENT_MTHD_SE    11739 non-null  int64
#  15  PAYMENT_AMT_WON    11739 non-null  int64
# ...

# %% [markdown]
# | CSV 컬럼명        | PDF 테이블/속성                | 의미(요약)                | 코드/참조              | 비고                                 |
# | ----------------- | ------------------------------ | ------------------------- | ---------------------- | ------------------------------------ |
# | TRAVEL_ID         | TN_ACTIVITY_CONSUME_HIS · 11-1 | 여행 ID                   | —                      | TN_TRAVEL의 여행 단위와 연결         |
# | VISIT_AREA_ID     | 11-2                           | 방문지 ID                 | —                      | TN_VISIT_AREA_INFO와 연결            |
# | ACTIVITY_TYPE_CD  | 11-3                           | 활동유형 **코드(대분류)** | 코드군 **‘ACT’**       | 범주 코드(설명은 코드 테이블 참조)   |
# | ACTIVITY_TYPE_SEQ | 11-4                           | 활동유형 **순번/세분류**  | —                      | 같은 활동 내 세부 구분(순번)         |
# | CONSUME_HIS_SEQ   | 11-5                           | 소비내역 **순번**         | —                      | 거래 레코드 식별에 사용              |
# | CONSUME_HIS_SNO   | 11-6                           | 소비내역 **부번**         | —                      | 한 순번 내 세부 항목 번호            |
# | PAYMENT_NUM       | 11-7                           | **소비 인원(명)**         | —                      | 단위: 명                             |
# | BRNO              | 11-8                           | **사업자등록번호**        | —                      | 점포/사업자 식별                     |
# | STORE_NM          | 11-9                           | **상호명(점포명)**        | —                      | 텍스트 정규화 권장                   |
# | ROAD_NM_ADDR      | 11-10                          | **도로명 주소**           | —                      | 주소 텍스트                          |
# | LOTNO_ADDR        | 11-11                          | **지번 주소**             | —                      | 주소 텍스트                          |
# | ROAD_NM_CD        | 11-12                          | **도로명 코드**           | —                      | 주소 코드(외부 행정코드와 매칭 가능) |
# | LOTNO_CD          | 11-13                          | **지번 코드**             | —                      | 주소 코드(외부 행정코드와 매칭 가능) |
# | PAYMENT_DT        | 11-14                          | **결제 일시(분 단위)**    | —                      | 형식: `YYYY-MM-DD HH:MI`             |
# | PAYMENT_MTHD_SE   | 11-15                          | **결제 방식 구분**        | 코드군 **‘PAY’**       | 카드/현금 등 수단 구분               |
# | PAYMENT_AMT_WON   | 11-16                          | **결제 금액(원)**         | —                      | 정수형 금액                          |
# | PAYMENT_ETC       | 11-17                          | **소비내역 기타(메모)**   | —                      | 자유 입력 텍스트                     |
# | SGG_CD            | 11-18                          | **시군구 코드**           | **TC_SGG** 테이블 참조 | 지역 행정구역 코드                   |

# %%
tn_activity_consume_his_df.describe()
# Out:
#        VISIT_AREA_ID  ACTIVITY_TYPE_CD  ACTIVITY_TYPE_SEQ  CONSUME_HIS_SEQ  \
# count   1.173900e+04      11739.000000       11739.000000     11739.000000
# mean    2.306941e+09          1.565466           0.491354         0.491354
# std     1.157979e+06          0.986639           1.122117         1.122117
# min     2.304280e+09          1.000000           0.000000         0.000000
# 25%     2.306050e+09          1.000000           0.000000         0.000000
# 50%     2.307050e+09          1.000000           0.000000         0.000000
# 75%     2.308180e+09          2.000000           0.000000         0.000000
# max     2.309180e+09          6.000000          15.000000        15.000000
#
#        CONSUME_HIS_SNO   PAYMENT_NUM          BRNO    ROAD_NM_CD  \
# count     11739.000000  11739.000000  9.805000e+03  1.024200e+04
# mean          1.017634      2.345004  3.630790e+09  3.440026e+06
# std           0.583857      1.327544  2.488112e+09  7.439536e+05
# ...

# %%
# 3. 결측치 및 이상치 탐색
# 결측치 탐색
tn_activity_consume_his_df.isnull().sum()
# Out:
# TRAVEL_ID                0
# VISIT_AREA_ID            0
# ACTIVITY_TYPE_CD         0
# ACTIVITY_TYPE_SEQ        0
# CONSUME_HIS_SEQ          0
# CONSUME_HIS_SNO          0
# PAYMENT_NUM              0
# BRNO                  1934
# STORE_NM                49
# ROAD_NM_ADDR           349
# LOTNO_ADDR            3869
# ROAD_NM_CD            1497
# LOTNO_CD              1497
# PAYMENT_DT            1378
# PAYMENT_MTHD_SE          0
# PAYMENT_AMT_WON          0
# PAYMENT_ETC           3370
# SGG_CD               10420
# dtype: int64

# %%
# 4. 데이터 시각화를 통한 탐색
# '활동유형(대분류) 비중 - ACTIVITY_TYPE_CD' 원형 그래프화

# 한글 폰트 (윈도우)
plt.rcParams['font.family'] = 'Malgun Gothic'   # 윈도우 기본 한글 폰트
plt.rcParams['axes.unicode_minus'] = False      # 음수 기호 깨짐 방지

df = tn_activity_consume_his_df
col = 'ACTIVITY_TYPE_CD'

# 라벨 매핑(있으면 채워서 사용, 없으면 숫자 그대로 표시)
type_map = {1:'취식', 2:'쇼핑/구매', 3:'체험 활동/입장 및 관람', 6:'기타'}  # 예시

# 빈도 집계 (NaN 포함하려면 .fillna('미상') 후 value_counts(dropna=False))
counts = df[col].value_counts()              # 많이 나온 순
# counts = df[col].value_counts().sort_index()  # 코드값 순으로 보고 싶으면

labels = [type_map.get(k, str(k)) for k in counts.index]
sizes  = counts.values
total  = sizes.sum()

# 작은 조각 강조(예: 6% 미만 조각만 explode)
min_pct_for_label = 6
explode = np.where(sizes / total * 100 < min_pct_for_label, 0.06, 0)

def autopct_fmt(p):
    # 작은 비율은 웨지 안쪽 표기 생략 → 범례로만 깔끔히 표시
    return f'{p:.1f}%' if p >= min_pct_for_label else ''

fig, ax = plt.subplots(figsize=(7,5))
wedges, _, autotexts = ax.pie(
    sizes,
    startangle=90,
    counterclock=False,
    labels=None,                           # 라벨은 범례에서 처리
    autopct=autopct_fmt,
    pctdistance=0.68,
    labeldistance=1.08,
    explode=explode,
    wedgeprops={'linewidth':1, 'edgecolor':'white'}  # 경계선으로 가독성↑
)
ax.axis('equal')
ax.set_title('활동유형(대분류) 비중 - ACTIVITY_TYPE_CD')

# 범례: 라벨 + 건수 + 비율
legend_labels = [f'{lab}  {cnt:,}건  ({cnt/total:.1%})'
                 for lab, cnt in zip(labels, sizes)]
ax.legend(wedges, legend_labels, title='범례',
          loc='center left', bbox_to_anchor=(1, 0.5))

# (옵션) 도넛 스타일 & 총 표본수 표기 — 원하면 주석 해제
# centre = plt.Circle((0,0), 0.55, fc='white')
# ax.add_artist(centre)
# ax.text(0, 0, f'N={total:,}', ha='center', va='center')

plt.tight_layout()
plt.show()
# Out:
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# /tmp/ipykernel_6126/316527707.py:56: UserWarning: Glyph 54876 (\N{HANGUL SYLLABLE HWAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6126/316527707.py:56: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6126/316527707.py:56: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6126/316527707.py:56: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6126/316527707.py:56: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6126/316527707.py:56: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
# 이상치 탐색을 위한 시각화
# tn_activity_consume_his_df.plot(kind='box')
exclude = [
   'TRAVEL_ID','CONSUME_HIS_SEQ','CONSUME_HIS_SNO','VISIT_AREA_ID','BRNO','STORE_NM',
   'ROAD_NM_ADDR','LOTNO_ADDR','PAYMENT_DT','PAYMENT_ETC','ACTIVITY_TYPE_CD','ACTIVITY_TYPE_SEQ',
   'PAYMENT_MTHD_SE','ROAD_NM_CD','LOTNO_CD','SGG_CD'
]
num_cols = tn_activity_consume_his_df.select_dtypes(include='number').columns.difference(exclude)

n = len(num_cols)
ncols = 4
nrows = math.ceil(n / ncols)

axes = tn_activity_consume_his_df[num_cols].plot(
    kind='box', subplots=True, layout=(nrows, ncols),
    figsize=(ncols*4, nrows*3), sharex=False, sharey=False
)
plt.tight_layout()
plt.show()
# Out:
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# ...

# %% [markdown]
# ##### 제외(박스플롯/수치형 이상치 대상 아님)
#
# - 식별자/순번(ID류): TRAVEL_ID, CONSUME_HIS_SEQ, CONSUME_HIS_SNO, VISIT_AREA_ID, BRNO
#
#   - 번호 크기에 의미가 없고, “큰 값=이상치”가 아님. 분포는 시스템 설계/입력 순서에 좌우됨.
#
# - 카테고리 코드(숫자 라벨): ACTIVITY_TYPE_CD, ACTIVITY_TYPE_SEQ, PAYMENT_MTHD_SE
#
#   - 숫자지만 “라벨”일 뿐 → 박스플롯의 사분위/거리 개념이 맞지 않음. 막대그래프/교차표로 보는 게 맞음.
#
# - 주소 코드(지리 라벨): ROAD_NM_CD, LOTNO_CD, SGG_CD
#
#   - 위치 식별키. 크기·거리 개념 없음. 외부 행정코드/좌표 매칭용일 때만 의미.
#
# - 문자열/날짜: STORE_NM, ROAD_NM_ADDR, LOTNO_ADDR, PAYMENT_DT, PAYMENT_ETC
#   - 숫자가 아니거나, 숫자로 강제 변환해도 이상치 개념이 부적절
#
# ##### 해당 이상치에 대해 논의 후 처리

# %%
# 5. 데이터 정제 및 전처리
# 드롭할 컬럼 목록만 정리
drop_cols = [
    'SGG_CD','ROAD_NM_ADDR','LOTNO_ADDR','ROAD_NM_CD','LOTNO_CD',
    'BRNO','PAYMENT_DT','CONSUME_HIS_SEQ','CONSUME_HIS_SNO'
]

# 원본은 보존하고, 없는 컬럼이 있어도 에러 없이 진행
tn_activity_consume_his_df_clean = tn_activity_consume_his_df.drop(
    columns=drop_cols, errors='ignore'
).copy()

# %% [markdown]
# ##### 활동소비내역 분류
#
# - 제거
#   - SGG_CD : 결측치 과다(11000개 가량 데이터 중 결측치 10000개 이상), 더 적합한 장소 관련 칼럼 여럿 보유.
#   - BRNO : 점포/사업자 식별에 사용되기에 주제 상 불필요.
#   - ROAD_NM_ADDR, LOTNO_ADDR : 방문지 데이터가 따로 존재하기에 중복을 피하기 위해 제거
#   - ROAD_NM_CD, LOTNO_CD : 위치 식별키. 크기·거리 개념 없음. 외부 행정코드/좌표 매칭용일 때만 의미.
#   - PAYMENT_DT : 결제 금액은 중요하지만, 결제 시간까지는 불필요하여 제거
#   - CONSUME_HIS_SEQ, CONSUME_HIS_SNO : 소비내역 순번, 부번 코드로, 중복을 피하기 위해 지정된 것이므로 실질적인 영향이 없는 데이터라 제거

# %%
tn_activity_consume_his_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11739 entries, 0 to 11738
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TRAVEL_ID          11739 non-null  object
#  1   VISIT_AREA_ID      11739 non-null  int64
#  2   ACTIVITY_TYPE_CD   11739 non-null  int64
#  3   ACTIVITY_TYPE_SEQ  11739 non-null  int64
#  4   PAYMENT_NUM        11739 non-null  int64
#  5   STORE_NM           11690 non-null  object
#  6   PAYMENT_MTHD_SE    11739 non-null  int64
#  7   PAYMENT_AMT_WON    11739 non-null  int64
#  8   PAYMENT_ETC        8369 non-null   object
# dtypes: int64(6), object(3)
# memory usage: 825.5+ KB

# %% [markdown]
# ### preprocessing.py 적용사항
# - 전처리 로직을 `preprocess_activity_consumption()` 함수로 통합해 `load_dataset('활동소비내역')` 기반으로 데이터를 읽어옵니다.
# - 기본 삭제 컬럼을 노트북에서 다루던 목록으로 정리하고 `drop_columns` 파라미터로 사용자 정의 열을 덧붙일 수 있게 했습니다.
# - 삭제 대상이 존재하지 않아도 `errors="ignore"` 옵션으로 오류 없이 데이터프레임을 반환합니다.
